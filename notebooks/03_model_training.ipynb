# %% [markdown]
# ## Phase 3 — Maintenance Decision Engine

# %%
from tensorflow.keras.models import load_model

model = load_model(
    "../models/bigru_rul_model.h5",
    compile=False
)

# %%
from tensorflow.keras.optimizers import Adam

model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='mse',
    metrics=['mae']
)

# %%
# Generate Predictions for Entire Validation Set
predictions = model.predict(X_val)

predictions = predictions.flatten()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Generate Predictions for Entire Validation Set
# ----> 2 predictions = model.predict(X_val)
#       4 predictions = predictions.flatten()
#
# NameError: name 'X_val' is not defined
